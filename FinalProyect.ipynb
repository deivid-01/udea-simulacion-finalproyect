# %% [markdown]
# Reading dataset

# %%
import pandas as pd
#Importing data file
url ='https://raw.githubusercontent.com/deivid-01/udea-simulacion-finalproyect/master/data/nbagames_stats.csv'

#Setting dataframe
df = pd.read_csv(url)


#Deleting rows
#dfSalary2016=dfSalary2016.drop(columns=["POSITION","TEAM"])

#Renaming cols
#dfSalary2016=dfSalary2016.rename(columns={"NAME":"Player","SALARY": "season16_17"})



df
# Out:
#       Unnamed: 0 Team  Game  ... Opp.Blocks Opp.Turnovers Opp.TotalFouls
# 0              1  ATL     1  ...          9             9             22
# 1              2  ATL     2  ...          5            18             26
# 2              3  ATL     3  ...          9            19             15
# 3              4  ATL     4  ...          7            19             30
# 4              5  ATL     5  ...          6            15             29
# ...          ...  ...   ...  ...        ...           ...            ...
# 9835       78119  WAS    78  ...          3             9             14
# 9836       79119  WAS    79  ...          3            16             14
# 9837       80119  WAS    80  ...          5            18             22
# 9838       81124  WAS    81  ...          1            16             18
# 9839       82119  WAS    82  ...          7            16             27
#
# [9840 rows x 41 columns]

# %%
## KEEPOUTPUT
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set()
sns.pairplot(df[cols])

# %%
cols = ["Age","Tm","MP","PER","PTS","FTA","3P","2P","FGA","TRB","season17_18"]
corrmat = df[cols].corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);
